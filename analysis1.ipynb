# %%
from feat import Detector

detector = Detector()

detector

# %%
from feat import Detector
from feat.utils.io import get_test_data_path
import os

detector = Detector()
test_data_dir = get_test_data_path()
test_video_path = os.path.join(test_data_dir, "analysis1.mp4")

# Show video
# from IPython.core.display import Video
# Video(test_video_path, embed=True)

# video_prediction = detector.detect_video("C:/Users/Public/Desktop/feat/analysis1.mp4", skip_frames=24)
video_prediction = detector.detect_video("C:/Users/Public/Desktop/feat/analysis1.mp4", skip_frames=2.9)
video_prediction.head()

video_prediction.shape

video_prediction.loc[[0, 867.1]].plot_detections(faceboxes=False, add_titles=False)

axes = video_prediction.emotions.plot()

video_prediction.to_csv("analysis1_01_30_2023.csv")
# Out:
# 100%|██████████| 300/300 [12:13<00:00,  2.44s/it]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 19
#      15 video_prediction.head()
#      17 video_prediction.shape
# ---> 19 video_prediction.loc[[0, 867.1]].plot_detections(faceboxes=False, add_titles=False)
#      21 axes = video_prediction.emotions.plot()
#      23 video_prediction.to_csv("analysis1_01_30_2023.csv")
#
# File c:\Users\Public\Desktop\feat\feat\data.py:1752, in Fex.plot_detections(self, faces, faceboxes, muscles, poses, gazes, add_titles, au_barplot, emotion_barplot, plot_original_image)
#    1748         warnings.simplefilter("ignore", UserWarning)
#    1749         video, audio, info = read_video(
#    1750             row["input"], output_format="TCHW"
#    1751         )
# -> 1752     img = video[row["frame"], :, :]
#    1753 color = "w"
#    1754 face_ax.imshow(img.permute([1, 2, 0]))
# ...

# %%
from feat import Detector
from feat.utils.io import get_test_data_path
import os

test_data_dir = get_test_data_path()
test_video_path = os.path.join(test_data_dir, "Spam.mp4")

# Show video
# from IPython.core.display import Video
# Video(test_video_path, embed=True)

# video_prediction = detector.detect_video("C:/Users/Public/Desktop/feat/Spam.mp4", skip_frames=24)
video_prediction = detector.detect_video("C:/Users/Public/Desktop/feat/Spam.mp4", skip_frames=9.9)
video_prediction.head()

video_prediction.shape

# video_prediction.loc[[48, 408]].plot_detections(faceboxes=False, add_titles=False)

axes = video_prediction.emotions.plot()

video_prediction.to_csv("analysis2_01_30_2023.csv")
